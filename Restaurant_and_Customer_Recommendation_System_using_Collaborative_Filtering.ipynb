# %% [markdown]
# ## Data Understanding

# %%
# Import library
import pandas as pd
import numpy as np 
from zipfile import ZipFile
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from pathlib import Path
import matplotlib.pyplot as plt

# %%
# !wget https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Out:
# --2021-10-19 18:14:09--  https://archive.ics.uci.edu/ml/machine-learning-databases/00232/RCdata.zip
# Resolving archive.ics.uci.edu (archive.ics.uci.edu)... 128.195.10.252
# Connecting to archive.ics.uci.edu (archive.ics.uci.edu)|128.195.10.252|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39674 (39K) [application/x-httpd-php]
# Saving to: ‘RCdata.zip’
#
# RCdata.zip          100%[===================>]  38.74K  --.-KB/s    in 0.01s
#
# 2021-10-19 18:14:09 (3.13 MB/s) - ‘RCdata.zip’ saved [39674/39674]

# %%
# !unzip /content/RCdata.zip
# Out:
# Archive:  /content/RCdata.zip
#   inflating: chefmozaccepts.csv
#   inflating: chefmozcuisine.csv
#   inflating: chefmozhours4.csv
#   inflating: chefmozparking.csv
#   inflating: geoplaces2.csv
#   inflating: rating_final.csv
#   inflating: README
#   inflating: usercuisine.csv
#   inflating: userpayment.csv
#   inflating: userprofile.csv

# %%
accepts = pd.read_csv('/content/chefmozaccepts.csv')
cuisine = pd.read_csv('/content/chefmozcuisine.csv')
hours = pd.read_csv('/content/chefmozhours4.csv')
parking = pd.read_csv('/content/chefmozparking.csv')
geo = pd.read_csv('/content/geoplaces2.csv', encoding = "ISO-8859-1")
usercuisine = pd.read_csv('/content/usercuisine.csv')
payment = pd.read_csv('/content/userpayment.csv')
profile = pd.read_csv('/content/userprofile.csv')
rating = pd.read_csv('/content/rating_final.csv')
 
print('Jumlah data pembayaran yang diterima restoran: ', len(accepts.placeID.unique()))
print('Jumlah data masakan pada restoran: ', len(cuisine.placeID.unique()))
print('Jumlah data waktu buka restoran: ', len(hours.placeID.unique()))
print('Jumlah data lokasi restoran: ', len(geo.placeID.unique()))
print('Jumlah data masakan pengguna: ', len(usercuisine.userID.unique()))
print('Jumlah data profil pengguna: ', len(profile.userID.unique()))
print('Jumlah data penilaian yang diberikan pengguna: ', len(rating.userID.unique()))
print('Jumlah data penilaian restoran: ', len(rating.placeID.unique()))
# Out:
# Jumlah data pembayaran yang diterima restoran:  615
# Jumlah data masakan pada restoran:  769
# Jumlah data waktu buka restoran:  694
# Jumlah data lokasi restoran:  130
# Jumlah data masakan pengguna:  138
# Jumlah data profil pengguna:  138
# Jumlah data penilaian yang diberikan pengguna:  138
# Jumlah data penilaian restoran:  130

# %%
# restaurant
# Menggabungkan seluruh placeID pada kategori Restaurant
resto_all = np.concatenate((
    accepts.placeID.unique(),
    cuisine.placeID.unique(),
    hours.placeID.unique(),
    parking.placeID.unique(),
    geo.placeID.unique()
))
 
# Mengurutkan data dan menghapus data yang sama
resto_all = np.sort(np.unique(resto_all))
 
print('Jumlah seluruh data restoran berdasarkan placeID: ', len(resto_all))
# Out:
# Jumlah seluruh data restoran berdasarkan placeID:  938

# %%
# user
# Menggabungkan seluruh userID
user_all = np.concatenate((
    usercuisine.userID.unique(),
    payment.userID.unique(),
    profile.userID.unique()
))
 
# Menghapus data yang sama kemudian mengurutkannya
user_all = np.sort(np.unique(user_all)) 
 
print('Jumlah seluruh user: ', len(user_all))
# Out:
# Jumlah seluruh user:  138

# %%
# user item rating
# Menggabungkan file accepts, geo, parking, hours ke dalam dataframe resto_info 
resto_info = pd.concat([accepts, geo, parking, hours])
 
# Menggabungkan dataframe rating dengan resto_info berdasarkan nilai placeID
resto = pd.merge(rating, resto_info , on='placeID', how='left')
resto
# Out:
#      userID  placeID  rating  ...  parking_lot         hours                  days
# 0     U1077   135085     2.0  ...          NaN           NaN                   NaN
# 1     U1077   135085     2.0  ...          NaN           NaN                   NaN
# 2     U1077   135085     2.0  ...       public           NaN                   NaN
# 3     U1077   135085     2.0  ...          NaN  00:00-00:00;  Mon;Tue;Wed;Thu;Fri;
# 4     U1077   135085     2.0  ...          NaN  00:00-00:00;                  Sat;
# ...     ...      ...     ...  ...          ...           ...                   ...
# 8073  U1068   132660     0.0  ...          NaN           NaN                   NaN
# 8074  U1068   132660     0.0  ...         none           NaN                   NaN
# 8075  U1068   132660     0.0  ...          NaN  00:00-23:30;  Mon;Tue;Wed;Thu;Fri;
# 8076  U1068   132660     0.0  ...          NaN  00:00-23:30;                  Sat;
# 8077  U1068   132660     0.0  ...          NaN  00:00-23:30;                  Sun;
#
# [8078 rows x 31 columns]

# %%
# Cek missing value dengan fungsi isnull()
resto.isnull().sum()
# Out:
# userID               0
# placeID              0
# rating               0
# food_rating          0
# service_rating       0
# user                 0
# resto                0
# Rpayment          5781
# latitude          6917
# longitude         6917
# the_geom_meter    6917
# name              6917
# address           6917
# city              6917
# state             6917
# country           6917
# fax               6917
# zip               6917
# alcohol           6917
# smoking_area      6917
# dress_code        6917
# accessibility     6917
# price             6917
# url               6917
# Rambience         6917
# franchise         6917
# area              6917
# other_services    6917
# parking_lot       6917
# hours             4619
# days              4619
# dtype: int64

# %%
# Menghitung jumlah rating, food_rating, dan service kemudian menggabungkannya berdasarkan placeID
resto.groupby('placeID').sum()
# Out:
#          rating  food_rating  service_rating  ...  resto    latitude    longitude
# placeID                                       ...
# 132560     12.0           24               6  ...    264   95.009216  -396.667653
# 132561     15.0           20              20  ...   1160   94.907276  -396.506024
# 132564     25.0           25              30  ...    480   94.923698  -396.580739
# 132572     90.0           90              84  ...   2880  332.124707 -1514.890677
# 132583     24.0           24              30  ...    384   75.689162  -396.937328
# ...         ...          ...             ...  ...    ...         ...          ...
# 135088     36.0           42              36  ...    540  113.256068  -595.319338
# 135104     48.0           80              48  ...    224  166.270875  -694.179039
# 135106     96.0           96              96  ...   5120  221.497088 -1009.760928
# 135108     65.0           65              55  ...   4675  243.498787 -1110.269437
# 135109     24.0           30              18  ...   1200   75.687139  -396.941400
#
# [130 rows x 7 columns]

# %%
# Definisikan dataframe rating ke dalam variabel all_resto_rate
all_resto_rate = rating
all_resto_rate
# Out:
#      userID  placeID  rating  food_rating  service_rating  user  resto
# 0     U1077   135085     2.0            2               2     0      0
# 1     U1077   135038     2.0            2               1     0      1
# 2     U1077   132825     2.0            2               2     0      2
# 3     U1077   135060     1.0            2               2     0      3
# 4     U1068   135104     1.0            1               2     1      4
# ...     ...      ...     ...          ...             ...   ...    ...
# 1156  U1043   132630     1.0            1               1   136      8
# 1157  U1011   132715     1.0            1               0   137     21
# 1158  U1068   132733     1.0            1               0     1     10
# 1159  U1068   132594     1.0            1               1     1     23
# 1160  U1068   132660     0.0            0               0     1     14
#
# [1161 rows x 7 columns]

# %%
# Menggabungkan all resto_rate dengan dataframe geo berdasarkan placeID
all_resto_name = pd.merge(all_resto_rate, geo[['placeID','name']], on='placeID', how='left')
 
# Print dataframe all_resto_name
all_resto_name
# Out:
#      userID  placeID  ...  resto                                   name
# 0     U1077   135085  ...      0                 Tortas Locas Hipocampo
# 1     U1077   135038  ...      1                  Restaurant la Chalita
# 2     U1077   132825  ...      2                        puesto de tacos
# 3     U1077   135060  ...      3                Restaurante Marisco Sam
# 4     U1068   135104  ...      4                                   vips
# ...     ...      ...  ...    ...                                    ...
# 1156  U1043   132630  ...      8                             palomo tec
# 1157  U1011   132715  ...     21                   tacos de la estacion
# 1158  U1068   132733  ...     10                          Little Cesarz
# 1159  U1068   132594  ...     23     tacos de barbacoa enfrente del Tec
# 1160  U1068   132660  ...     14  carnitas mata calle Emilio Portes Gil
#
# [1161 rows x 8 columns]

# %%
# Menggabungkan dataframe cuisine dengan all_resto_name dan memasukkannya ke dalam variabel all_resto 
all_resto = pd.merge(all_resto_name, cuisine, on='placeID', how='left')
all_resto
# Out:
#      userID  placeID  ...                                   name   Rcuisine
# 0     U1077   135085  ...                 Tortas Locas Hipocampo  Fast_Food
# 1     U1077   135038  ...                  Restaurant la Chalita        NaN
# 2     U1077   132825  ...                        puesto de tacos    Mexican
# 3     U1077   135060  ...                Restaurante Marisco Sam    Seafood
# 4     U1068   135104  ...                                   vips    Mexican
# ...     ...      ...  ...                                    ...        ...
# 1326  U1043   132630  ...                             palomo tec    Mexican
# 1327  U1011   132715  ...                   tacos de la estacion    Mexican
# 1328  U1068   132733  ...                          Little Cesarz   Pizzeria
# 1329  U1068   132594  ...     tacos de barbacoa enfrente del Tec    Mexican
# 1330  U1068   132660  ...  carnitas mata calle Emilio Portes Gil        NaN
#
# [1331 rows x 9 columns]

# %%
# Mengecek missing value pada dataframe all_resto
all_resto.isnull().sum()
# Out:
# userID              0
# placeID             0
# rating              0
# food_rating         0
# service_rating      0
# user                0
# resto               0
# name                0
# Rcuisine          288
# dtype: int64

# %%
# Membersihkan missing value dengan fungsi dropna()
all_resto_clean = all_resto.dropna()
all_resto_clean
# Out:
#      userID  placeID  ...                                name   Rcuisine
# 0     U1077   135085  ...              Tortas Locas Hipocampo  Fast_Food
# 2     U1077   132825  ...                     puesto de tacos    Mexican
# 3     U1077   135060  ...             Restaurante Marisco Sam    Seafood
# 4     U1068   135104  ...                                vips    Mexican
# 5     U1068   132740  ...       Carreton de Flautas y Migadas    Mexican
# ...     ...      ...  ...                                 ...        ...
# 1325  U1043   132732  ...                  Taqueria EL amigo     Mexican
# 1326  U1043   132630  ...                          palomo tec    Mexican
# 1327  U1011   132715  ...                tacos de la estacion    Mexican
# 1328  U1068   132733  ...                       Little Cesarz   Pizzeria
# 1329  U1068   132594  ...  tacos de barbacoa enfrente del Tec    Mexican
#
# [1043 rows x 9 columns]

# %%
# Mengurutkan resto berdasarkan PlaceID kemudian memasukkannya ke dalam variabel fix_resto
fix_resto = all_resto_clean.sort_values('placeID', ascending=True)
fix_resto
# Out:
#      userID  placeID  rating  ...  resto                        name   Rcuisine
# 1303  U1087   132560     1.0  ...     11          puesto de gorditas   Regional
# 1288  U1050   132560     0.0  ...     11          puesto de gorditas   Regional
# 14    U1067   132560     1.0  ...     11          puesto de gorditas   Regional
# 42    U1082   132560     0.0  ...     11          puesto de gorditas   Regional
# 1052  U1013   132572     1.0  ...     32                Cafe Chaires  Cafeteria
# ...     ...      ...     ...  ...    ...                         ...        ...
# 438   U1024   135106     1.0  ...     64  El Rincón de San Francisco    Mexican
# 178   U1020   135109     2.0  ...     50                   Paniroles    Italian
# 1071  U1041   135109     1.0  ...     50                   Paniroles    Italian
# 99    U1030   135109     0.0  ...     50                   Paniroles    Italian
# 180   U1051   135109     1.0  ...     50                   Paniroles    Italian
#
# [1043 rows x 9 columns]

# %%
# Mengecek berapa jumlah fix_resto
len(fix_resto.placeID.unique())
# Out:
# 95

# %%
# Mengecek kategori masakan yang unik
fix_resto.Rcuisine.unique()
# Out:
# array(['Regional', 'Cafeteria', 'American', 'Mexican', 'Fast_Food',
#        'Italian', 'Armenian', 'Pizzeria', 'Japanese', 'Vietnamese',
#        'Family', 'International', 'Game', 'Burgers', 'Bakery', 'Bar',
#        'Breakfast-Brunch', 'Bar_Pub_Brewery', 'Mediterranean',
#        'Cafe-Coffee_Shop', 'Contemporary', 'Seafood', 'Chinese'],
#       dtype=object)

# %%
# Mengubah nama kategori masakan ‘Game’ menjadi ‘American’
fix_resto = fix_resto.replace('Game', 'American')
fix_resto[fix_resto['name'] == 'KFC']
# Out:
#      userID  placeID  rating  food_rating  ...  user  resto  name  Rcuisine
# 781   U1015   132851     1.0            1  ...    11    107   KFC  American
# 508   U1052   132851     1.0            0  ...    63    107   KFC  American
# 780   U1015   132851     1.0            1  ...    11    107   KFC  American
# 509   U1052   132851     1.0            0  ...    63    107   KFC  American
# 708   U1008   132851     1.0            1  ...    83    107   KFC  American
# 707   U1008   132851     1.0            1  ...    83    107   KFC  American
# 770   U1037   132851     2.0            2  ...    62    107   KFC  American
# 769   U1037   132851     2.0            2  ...    62    107   KFC  American
# 1187  U1131   132851     2.0            2  ...   122    107   KFC  American
# 574   U1069   132851     1.0            0  ...    71    107   KFC  American
# 1188  U1131   132851     2.0            2  ...   122    107   KFC  American
# 764   U1111   132851     2.0            1  ...    90    107   KFC  American
# 763   U1111   132851     2.0            1  ...    90    107   KFC  American
# 573   U1069   132851     1.0            0  ...    71    107   KFC  American
#
# [14 rows x 9 columns]

# %%
# Membuat variabel preparation yang berisi dataframe fix_resto kemudian mengurutkan berdasarkan placeID
preparation = fix_resto
preparation.sort_values('placeID')
# Out:
#      userID  placeID  rating  ...  resto                        name   Rcuisine
# 1303  U1087   132560     1.0  ...     11          puesto de gorditas   Regional
# 1288  U1050   132560     0.0  ...     11          puesto de gorditas   Regional
# 14    U1067   132560     1.0  ...     11          puesto de gorditas   Regional
# 42    U1082   132560     0.0  ...     11          puesto de gorditas   Regional
# 184   U1055   132572     2.0  ...     32                Cafe Chaires  Cafeteria
# ...     ...      ...     ...  ...    ...                         ...        ...
# 1224  U1002   135106     1.0  ...     64  El Rincón de San Francisco    Mexican
# 99    U1030   135109     0.0  ...     50                   Paniroles    Italian
# 178   U1020   135109     2.0  ...     50                   Paniroles    Italian
# 1071  U1041   135109     1.0  ...     50                   Paniroles    Italian
# 180   U1051   135109     1.0  ...     50                   Paniroles    Italian
#
# [1043 rows x 9 columns]

# %%
# Membuang data duplikat pada variabel preparation
preparation = preparation.drop_duplicates('placeID')
preparation
# Out:
#      userID  placeID  ...                                name   Rcuisine
# 1303  U1087   132560  ...                  puesto de gorditas   Regional
# 1052  U1013   132572  ...                        Cafe Chaires  Cafeteria
# 168   U1118   132583  ...                    McDonalds Centro   American
# 24    U1107   132584  ...                  Gorditas Dona Tota    Mexican
# 1329  U1068   132594  ...  tacos de barbacoa enfrente del Tec    Mexican
# ...     ...      ...  ...                                 ...        ...
# 681   U1095   135086  ...         Mcdonalds Parque Tangamanga  Fast_Food
# 175   U1020   135088  ...                   Cafeteria cenidet  Cafeteria
# 4     U1068   135104  ...                                vips    Mexican
# 488   U1004   135106  ...          El Rincón de San Francisco    Mexican
# 178   U1020   135109  ...                           Paniroles    Italian
#
# [95 rows x 9 columns]

# %%
# Mengonversi data series ‘placeID’ menjadi dalam bentuk list
resto_id = preparation['placeID'].tolist()
 
# Mengonversi data series ‘Name’ menjadi dalam bentuk list
resto_name = preparation['name'].tolist()
 
# Mengonversi data series ‘Rcuisine’ menjadi dalam bentuk list
resto_cuisine = preparation['Rcuisine'].tolist()
 
print(len(resto_id))
print(len(resto_name))
print(len(resto_cuisine))
# Out:
# 95
# 95
# 95

# %%
# Membuat dictionary untuk data ‘resto_id’, ‘resto_name’, dan ‘cuisine’
resto_new = pd.DataFrame({
    'id': resto_id,
    'resto_name': resto_name,
    'cuisine': resto_cuisine
})
resto_new
# Out:
#         id                          resto_name    cuisine
# 0   132560                  puesto de gorditas   Regional
# 1   132572                        Cafe Chaires  Cafeteria
# 2   132583                    McDonalds Centro   American
# 3   132584                  Gorditas Dona Tota    Mexican
# 4   132594  tacos de barbacoa enfrente del Tec    Mexican
# ..     ...                                 ...        ...
# 90  135086         Mcdonalds Parque Tangamanga  Fast_Food
# 91  135088                   Cafeteria cenidet  Cafeteria
# 92  135104                                vips    Mexican
# 93  135106          El Rincón de San Francisco    Mexican
# 94  135109                           Paniroles    Italian
#
# [95 rows x 3 columns]

# %%
# Membaca dataset
 
df = rating
df
# Out:
#      userID  placeID  rating  food_rating  service_rating  user  resto
# 0     U1077   135085     2.0            2               2     0      0
# 1     U1077   135038     2.0            2               1     0      1
# 2     U1077   132825     2.0            2               2     0      2
# 3     U1077   135060     1.0            2               2     0      3
# 4     U1068   135104     1.0            1               2     1      4
# ...     ...      ...     ...          ...             ...   ...    ...
# 1156  U1043   132630     1.0            1               1   136      8
# 1157  U1011   132715     1.0            1               0   137     21
# 1158  U1068   132733     1.0            1               0     1     10
# 1159  U1068   132594     1.0            1               1     1     23
# 1160  U1068   132660     0.0            0               0     1     14
#
# [1161 rows x 7 columns]

# %% [markdown]
# ## Data Preprocessing

# %%
# Mengubah userID menjadi list tanpa nilai yang sama
user_ids = df['userID'].unique().tolist()
print('list userID: ', user_ids)
 
# Melakukan encoding userID
user_to_user_encoded = {x: i for i, x in enumerate(user_ids)}
print('encoded userID : ', user_to_user_encoded)
 
# Melakukan proses encoding angka ke ke userID
user_encoded_to_user = {i: x for i, x in enumerate(user_ids)}
print('encoded angka ke userID: ', user_encoded_to_user)
# Out:
# list userID:  ['U1077', 'U1068', 'U1067', 'U1103', 'U1107', 'U1044', 'U1070', 'U1031', 'U1082', 'U1023', 'U1060', 'U1015', 'U1123', 'U1021', 'U1026', 'U1083', 'U1108', 'U1012', 'U1093', 'U1030', 'U1066', 'U1127', 'U1017', 'U1100', 'U1133', 'U1118', 'U1072', 'U1080', 'U1063', 'U1074', 'U1117', 'U1020', 'U1051', 'U1055', 'U1053', 'U1035', 'U1064', 'U1081', 'U1001', 'U1014', 'U1088', 'U1056', 'U1134', 'U1106', 'U1126', 'U1124', 'U1018', 'U1125', 'U1119', 'U1076', 'U1022', 'U1094', 'U1116', 'U1105', 'U1075', 'U1007', 'U1115', 'U1024', 'U1132', 'U1005', 'U1120', 'U1004', 'U1037', 'U1052', 'U1036', 'U1038', 'U1071', 'U1114', 'U1084', 'U1049', 'U1019', 'U1069', 'U1113', 'U1104', 'U1079', 'U1045', 'U1009', 'U1016', 'U1047', 'U1095', 'U1034', 'U1078', 'U1099', 'U1008', 'U1040', 'U1121', 'U1110', 'U1042', 'U1013', 'U1054', 'U1111', 'U1128', 'U1062', 'U1101', 'U1135', 'U1032', 'U1048', 'U1092', 'U1085', 'U1109', 'U1102', 'U1098', 'U1046', 'U1122', 'U1138', 'U1033', 'U1089', 'U1003', 'U1091', 'U1027', 'U1029', 'U1086', 'U1137', 'U1090', 'U1061', 'U1041', 'U1059', 'U1112', 'U1057', 'U1025', 'U1097', 'U1006', 'U1131', 'U1073', 'U1058', 'U1002', 'U1096', 'U1136', 'U1010', 'U1028', 'U1050', 'U1129', 'U1087', 'U1065', 'U1039', 'U1130', 'U1043', 'U1011']
# encoded userID :  {'U1077': 0, 'U1068': 1, 'U1067': 2, 'U1103': 3, 'U1107': 4, 'U1044': 5, 'U1070': 6, 'U1031': 7, 'U1082': 8, 'U1023': 9, 'U1060': 10, 'U1015': 11, 'U1123': 12, 'U1021': 13, 'U1026': 14, 'U1083': 15, 'U1108': 16, 'U1012': 17, 'U1093': 18, 'U1030': 19, 'U1066': 20, 'U1127': 21, 'U1017': 22, 'U1100': 23, 'U1133': 24, 'U1118': 25, 'U1072': 26, 'U1080': 27, 'U1063': 28, 'U1074': 29, 'U1117': 30, 'U1020': 31, 'U1051': 32, 'U1055': 33, 'U1053': 34, 'U1035': 35, 'U1064': 36, 'U1081': 37, 'U1001': 38, 'U1014': 39, 'U1088': 40, 'U1056': 41, 'U1134': 42, 'U1106': 43, 'U1126': 44, 'U1124': 45, 'U1018': 46, 'U1125': 47, 'U1119': 48, 'U1076': 49, 'U1022': 50, 'U1094': 51, 'U1116': 52, 'U1105': 53, 'U1075': 54, 'U1007': 55, 'U1115': 56, 'U1024': 57, 'U1132': 58, 'U1005': 59, 'U1120': 60, 'U1004': 61, 'U1037': 62, 'U1052': 63, 'U1036': 64, 'U1038': 65, 'U1071': 66, 'U1114': 67, 'U1084': 68, 'U1049': 69, 'U1019': 70, 'U1069': 71, 'U1113': 72, 'U1104': 73, 'U1079': 74, 'U1045': 75, 'U1009': 76, 'U1016': 77, 'U1047': 78, 'U1095': 79, 'U1034': 80, 'U1078': 81, 'U1099': 82, 'U1008': 83, 'U1040': 84, 'U1121': 85, 'U1110': 86, 'U1042': 87, 'U1013': 88, 'U1054': 89, 'U1111': 90, 'U1128': 91, 'U1062': 92, 'U1101': 93, 'U1135': 94, 'U1032': 95, 'U1048': 96, 'U1092': 97, 'U1085': 98, 'U1109': 99, 'U1102': 100, 'U1098': 101, 'U1046': 102, 'U1122': 103, 'U1138': 104, 'U1033': 105, 'U1089': 106, 'U1003': 107, 'U1091': 108, 'U1027': 109, 'U1029': 110, 'U1086': 111, 'U1137': 112, 'U1090': 113, 'U1061': 114, 'U1041': 115, 'U1059': 116, 'U1112': 117, 'U1057': 118, 'U1025': 119, 'U1097': 120, 'U1006': 121, 'U1131': 122, 'U1073': 123, 'U1058': 124, 'U1002': 125, 'U1096': 126, 'U1136': 127, 'U1010': 128, 'U1028': 129, 'U1050': 130, 'U1129': 131, 'U1087': 132, 'U1065': 133, 'U1039': 134, 'U1130': 135, 'U1043': 136, 'U1011': 137}
# encoded angka ke userID:  {0: 'U1077', 1: 'U1068', 2: 'U1067', 3: 'U1103', 4: 'U1107', 5: 'U1044', 6: 'U1070', 7: 'U1031', 8: 'U1082', 9: 'U1023', 10: 'U1060', 11: 'U1015', 12: 'U1123', 13: 'U1021', 14: 'U1026', 15: 'U1083', 16: 'U1108', 17: 'U1012', 18: 'U1093', 19: 'U1030', 20: 'U1066', 21: 'U1127', 22: 'U1017', 23: 'U1100', 24: 'U1133', 25: 'U1118', 26: 'U1072', 27: 'U1080', 28: 'U1063', 29: 'U1074', 30: 'U1117', 31: 'U1020', 32: 'U1051', 33: 'U1055', 34: 'U1053', 35: 'U1035', 36: 'U1064', 37: 'U1081', 38: 'U1001', 39: 'U1014', 40: 'U1088', 41: 'U1056', 42: 'U1134', 43: 'U1106', 44: 'U1126', 45: 'U1124', 46: 'U1018', 47: 'U1125', 48: 'U1119', 49: 'U1076', 50: 'U1022', 51: 'U1094', 52: 'U1116', 53: 'U1105', 54: 'U1075', 55: 'U1007', 56: 'U1115', 57: 'U1024', 58: 'U1132', 59: 'U1005', 60: 'U1120', 61: 'U1004', 62: 'U1037', 63: 'U1052', 64: 'U1036', 65: 'U1038', 66: 'U1071', 67: 'U1114', 68: 'U1084', 69: 'U1049', 70: 'U1019', 71: 'U1069', 72: 'U1113', 73: 'U1104', 74: 'U1079', 75: 'U1045', 76: 'U1009', 77: 'U1016', 78: 'U1047', 79: 'U1095', 80: 'U1034', 81: 'U1078', 82: 'U1099', 83: 'U1008', 84: 'U1040', 85: 'U1121', 86: 'U1110', 87: 'U1042', 88: 'U1013', 89: 'U1054', 90: 'U1111', 91: 'U1128', 92: 'U1062', 93: 'U1101', 94: 'U1135', 95: 'U1032', 96: 'U1048', 97: 'U1092', 98: 'U1085', 99: 'U1109', 100: 'U1102', 101: 'U1098', 102: 'U1046', 103: 'U1122', 104: 'U1138', 105: 'U1033', 106: 'U1089', 107: 'U1003', 108: 'U1091', 109: 'U1027', 110: 'U1029', 111: 'U1086', 112: 'U1137', 113: 'U1090', 114: 'U1061', 115: 'U1041', 116: 'U1059', 117: 'U1112', 118: 'U1057', 119: 'U1025', 120: 'U1097', 121: 'U1006', 122: 'U1131', 123: 'U1073', 124: 'U1058', 125: 'U1002', 126: 'U1096', 127: 'U1136', 128: 'U1010', 129: 'U1028', 130: 'U1050', 131: 'U1129', 132: 'U1087', 133: 'U1065', 134: 'U1039', 135: 'U1130', 136: 'U1043', 137: 'U1011'}

# %%
# Mengubah placeID menjadi list tanpa nilai yang sama
resto_ids = df['placeID'].unique().tolist()
 
# Melakukan proses encoding placeID
resto_to_resto_encoded = {x: i for i, x in enumerate(resto_ids)}
 
# Melakukan proses encoding angka ke placeID
resto_encoded_to_resto = {i: x for i, x in enumerate(resto_ids)}
 
# petakan userID dan placeID ke dataframe yang berkaitan.
 
# Mapping userID ke dataframe user
df['user'] = df['userID'].map(user_to_user_encoded)
 
# Mapping placeID ke dataframe resto
df['resto'] = df['placeID'].map(resto_to_resto_encoded)

# %%
# Mendapatkan jumlah user
num_users = len(user_to_user_encoded)
print(num_users)
 
# Mendapatkan jumlah resto
num_resto = len(resto_encoded_to_resto)
print(num_resto)
 
# Mengubah rating menjadi nilai float
df['rating'] = df['rating'].values.astype(np.float32)
 
# Nilai minimum rating
min_rating = min(df['rating'])
 
# Nilai maksimal rating
max_rating = max(df['rating'])
 
print('Number of User: {}, Number of Resto: {}, Min Rating: {}, Max Rating: {}'.format(
    num_users, num_resto, min_rating, max_rating
))
# Out:
# 138
# 130
# Number of User: 138, Number of Resto: 130, Min Rating: 0.0, Max Rating: 2.0

# %%
# Mengacak dataset
df = df.sample(frac=1, random_state=42)
df
# Out:
#      userID  placeID  rating  food_rating  service_rating  user  resto
# 538   U1052   132870     1.0            1               1    63    116
# 673   U1015   132869     2.0            2               2    11    115
# 578   U1047   132875     0.0            0               0    78    117
# 242   U1056   135076     2.0            2               2    41     71
# 1063  U1002   135106     1.0            1               1   125     64
# ...     ...      ...     ...          ...             ...   ...    ...
# 1044  U1073   135065     0.0            0               0   123     94
# 1095  U1058   135062     2.0            2               2   124     76
# 1130  U1087   132660     1.0            1               0   132     14
# 860   U1029   132937     1.0            1               1   110    126
# 1126  U1028   132663     0.0            0               0   129      6
#
# [1161 rows x 7 columns]

# %%
# Membuat variabel x untuk mencocokkan data user dan resto menjadi satu value
x = df[['user', 'resto']].values
 
# Membuat variabel y untuk membuat rating dari hasil 
y = df['rating'].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
 
# Membagi menjadi 80% data train dan 20% data validasi
train_indices = int(0.8 * df.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:]
)
 
print(x, y)
# Out:
# [[ 63 116]
#  [ 11 115]
#  [ 78 117]
#  ...
#  [132  14]
#  [110 126]
#  [129   6]] [0.5 1.  0.  ... 0.5 0.5 0. ]

# %% [markdown]
# ## Model Development dengan Collaborative Filtering

# %%
class RecommenderNet(tf.keras.Model):
 
  # Insialisasi fungsi
  def __init__(self, num_users, num_resto, embedding_size, **kwargs):
    super(RecommenderNet, self).__init__(**kwargs)
    self.num_users = num_users
    self.num_resto = num_resto
    self.embedding_size = embedding_size
    self.user_embedding = layers.Embedding( # layer embedding user
        num_users,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.user_bias = layers.Embedding(num_users, 1) # layer embedding user bias
    self.resto_embedding = layers.Embedding( # layer embeddings resto
        num_resto,
        embedding_size,
        embeddings_initializer = 'he_normal',
        embeddings_regularizer = keras.regularizers.l2(1e-6)
    )
    self.resto_bias = layers.Embedding(num_resto, 1) # layer embedding resto bias
 
  def call(self, inputs):
    user_vector = self.user_embedding(inputs[:,0]) # memanggil layer embedding 1
    user_bias = self.user_bias(inputs[:, 0]) # memanggil layer embedding 2
    resto_vector = self.resto_embedding(inputs[:, 1]) # memanggil layer embedding 3
    resto_bias = self.resto_bias(inputs[:, 1]) # memanggil layer embedding 4
 
    dot_user_resto = tf.tensordot(user_vector, resto_vector, 2) 
 
    x = dot_user_resto + user_bias + resto_bias
    
    return tf.nn.sigmoid(x) # activation sigmoid

# %%
# proses compile model
model = RecommenderNet(num_users, num_resto, 50) # inisialisasi model
 
# model compile
model.compile(
    loss = tf.keras.losses.BinaryCrossentropy(),
    optimizer = keras.optimizers.Adam(learning_rate=0.001),
    metrics=[tf.keras.metrics.RootMeanSquaredError()]
)

# %%
# Memulai training
 
history = model.fit(
    x = x_train,
    y = y_train,
    batch_size = 8,
    epochs = 100,
    validation_data = (x_val, y_val)
)
# Out:
# Epoch 1/100
# 116/116 [==============================] - 1s 3ms/step - loss: 0.7042 - root_mean_squared_error: 0.4053 - val_loss: 0.7185 - val_root_mean_squared_error: 0.4161
# Epoch 2/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6709 - root_mean_squared_error: 0.3846 - val_loss: 0.7130 - val_root_mean_squared_error: 0.4129
# Epoch 3/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6672 - root_mean_squared_error: 0.3823 - val_loss: 0.7083 - val_root_mean_squared_error: 0.4100
# Epoch 4/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6550 - root_mean_squared_error: 0.3744 - val_loss: 0.7040 - val_root_mean_squared_error: 0.4074
# Epoch 5/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6447 - root_mean_squared_error: 0.3678 - val_loss: 0.7024 - val_root_mean_squared_error: 0.4065
# Epoch 6/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6412 - root_mean_squared_error: 0.3656 - val_loss: 0.6993 - val_root_mean_squared_error: 0.4045
# Epoch 7/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6313 - root_mean_squared_error: 0.3593 - val_loss: 0.6981 - val_root_mean_squared_error: 0.4037
# Epoch 8/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6150 - root_mean_squared_error: 0.3487 - val_loss: 0.6946 - val_root_mean_squared_error: 0.4016
# Epoch 9/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6199 - root_mean_squared_error: 0.3518 - val_loss: 0.6914 - val_root_mean_squared_error: 0.3997
# Epoch 10/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6132 - root_mean_squared_error: 0.3475 - val_loss: 0.6887 - val_root_mean_squared_error: 0.3981
# Epoch 11/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.6053 - root_mean_squared_error: 0.3421 - val_loss: 0.6860 - val_root_mean_squared_error: 0.3964
# Epoch 12/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5870 - root_mean_squared_error: 0.3299 - val_loss: 0.6833 - val_root_mean_squared_error: 0.3948
# Epoch 13/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5892 - root_mean_squared_error: 0.3312 - val_loss: 0.6813 - val_root_mean_squared_error: 0.3935
# Epoch 14/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5830 - root_mean_squared_error: 0.3270 - val_loss: 0.6793 - val_root_mean_squared_error: 0.3922
# Epoch 15/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5888 - root_mean_squared_error: 0.3309 - val_loss: 0.6765 - val_root_mean_squared_error: 0.3906
# Epoch 16/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5840 - root_mean_squared_error: 0.3276 - val_loss: 0.6744 - val_root_mean_squared_error: 0.3892
# Epoch 17/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5740 - root_mean_squared_error: 0.3209 - val_loss: 0.6711 - val_root_mean_squared_error: 0.3872
# Epoch 18/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5626 - root_mean_squared_error: 0.3129 - val_loss: 0.6688 - val_root_mean_squared_error: 0.3857
# Epoch 19/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5566 - root_mean_squared_error: 0.3092 - val_loss: 0.6667 - val_root_mean_squared_error: 0.3845
# Epoch 20/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5566 - root_mean_squared_error: 0.3092 - val_loss: 0.6643 - val_root_mean_squared_error: 0.3830
# Epoch 21/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5578 - root_mean_squared_error: 0.3095 - val_loss: 0.6601 - val_root_mean_squared_error: 0.3804
# Epoch 22/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5516 - root_mean_squared_error: 0.3055 - val_loss: 0.6574 - val_root_mean_squared_error: 0.3788
# Epoch 23/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5495 - root_mean_squared_error: 0.3038 - val_loss: 0.6548 - val_root_mean_squared_error: 0.3771
# Epoch 24/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5485 - root_mean_squared_error: 0.3035 - val_loss: 0.6530 - val_root_mean_squared_error: 0.3761
# Epoch 25/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5433 - root_mean_squared_error: 0.2997 - val_loss: 0.6516 - val_root_mean_squared_error: 0.3752
# Epoch 26/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5433 - root_mean_squared_error: 0.3000 - val_loss: 0.6497 - val_root_mean_squared_error: 0.3740
# Epoch 27/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5399 - root_mean_squared_error: 0.2969 - val_loss: 0.6484 - val_root_mean_squared_error: 0.3733
# Epoch 28/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5361 - root_mean_squared_error: 0.2950 - val_loss: 0.6472 - val_root_mean_squared_error: 0.3726
# Epoch 29/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5265 - root_mean_squared_error: 0.2881 - val_loss: 0.6448 - val_root_mean_squared_error: 0.3711
# Epoch 30/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5322 - root_mean_squared_error: 0.2914 - val_loss: 0.6427 - val_root_mean_squared_error: 0.3698
# Epoch 31/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5260 - root_mean_squared_error: 0.2879 - val_loss: 0.6407 - val_root_mean_squared_error: 0.3686
# Epoch 32/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5209 - root_mean_squared_error: 0.2842 - val_loss: 0.6395 - val_root_mean_squared_error: 0.3679
# Epoch 33/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5239 - root_mean_squared_error: 0.2862 - val_loss: 0.6372 - val_root_mean_squared_error: 0.3666
# Epoch 34/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5234 - root_mean_squared_error: 0.2853 - val_loss: 0.6353 - val_root_mean_squared_error: 0.3654
# Epoch 35/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5141 - root_mean_squared_error: 0.2791 - val_loss: 0.6329 - val_root_mean_squared_error: 0.3639
# Epoch 36/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5162 - root_mean_squared_error: 0.2810 - val_loss: 0.6315 - val_root_mean_squared_error: 0.3631
# Epoch 37/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5188 - root_mean_squared_error: 0.2827 - val_loss: 0.6297 - val_root_mean_squared_error: 0.3620
# Epoch 38/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5166 - root_mean_squared_error: 0.2804 - val_loss: 0.6291 - val_root_mean_squared_error: 0.3617
# Epoch 39/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5149 - root_mean_squared_error: 0.2790 - val_loss: 0.6258 - val_root_mean_squared_error: 0.3595
# Epoch 40/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5077 - root_mean_squared_error: 0.2741 - val_loss: 0.6244 - val_root_mean_squared_error: 0.3588
# Epoch 41/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5050 - root_mean_squared_error: 0.2719 - val_loss: 0.6216 - val_root_mean_squared_error: 0.3570
# Epoch 42/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5051 - root_mean_squared_error: 0.2727 - val_loss: 0.6193 - val_root_mean_squared_error: 0.3555
# Epoch 43/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5031 - root_mean_squared_error: 0.2712 - val_loss: 0.6166 - val_root_mean_squared_error: 0.3538
# Epoch 44/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4977 - root_mean_squared_error: 0.2677 - val_loss: 0.6162 - val_root_mean_squared_error: 0.3537
# Epoch 45/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5058 - root_mean_squared_error: 0.2733 - val_loss: 0.6159 - val_root_mean_squared_error: 0.3536
# Epoch 46/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4983 - root_mean_squared_error: 0.2677 - val_loss: 0.6165 - val_root_mean_squared_error: 0.3540
# Epoch 47/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5012 - root_mean_squared_error: 0.2697 - val_loss: 0.6147 - val_root_mean_squared_error: 0.3528
# Epoch 48/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4974 - root_mean_squared_error: 0.2675 - val_loss: 0.6110 - val_root_mean_squared_error: 0.3506
# Epoch 49/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.5003 - root_mean_squared_error: 0.2697 - val_loss: 0.6114 - val_root_mean_squared_error: 0.3509
# Epoch 50/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4906 - root_mean_squared_error: 0.2632 - val_loss: 0.6108 - val_root_mean_squared_error: 0.3506
# Epoch 51/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4885 - root_mean_squared_error: 0.2610 - val_loss: 0.6108 - val_root_mean_squared_error: 0.3507
# Epoch 52/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4904 - root_mean_squared_error: 0.2640 - val_loss: 0.6116 - val_root_mean_squared_error: 0.3512
# Epoch 53/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4914 - root_mean_squared_error: 0.2635 - val_loss: 0.6103 - val_root_mean_squared_error: 0.3506
# Epoch 54/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4904 - root_mean_squared_error: 0.2619 - val_loss: 0.6089 - val_root_mean_squared_error: 0.3498
# Epoch 55/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4911 - root_mean_squared_error: 0.2630 - val_loss: 0.6071 - val_root_mean_squared_error: 0.3487
# Epoch 56/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4903 - root_mean_squared_error: 0.2615 - val_loss: 0.6076 - val_root_mean_squared_error: 0.3491
# Epoch 57/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4887 - root_mean_squared_error: 0.2609 - val_loss: 0.6059 - val_root_mean_squared_error: 0.3481
# Epoch 58/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4830 - root_mean_squared_error: 0.2572 - val_loss: 0.6048 - val_root_mean_squared_error: 0.3476
# Epoch 59/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4830 - root_mean_squared_error: 0.2578 - val_loss: 0.6046 - val_root_mean_squared_error: 0.3474
# Epoch 60/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4785 - root_mean_squared_error: 0.2543 - val_loss: 0.6031 - val_root_mean_squared_error: 0.3465
# Epoch 61/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4781 - root_mean_squared_error: 0.2538 - val_loss: 0.6016 - val_root_mean_squared_error: 0.3455
# Epoch 62/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4790 - root_mean_squared_error: 0.2535 - val_loss: 0.6019 - val_root_mean_squared_error: 0.3457
# Epoch 63/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4788 - root_mean_squared_error: 0.2546 - val_loss: 0.6014 - val_root_mean_squared_error: 0.3456
# Epoch 64/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4750 - root_mean_squared_error: 0.2515 - val_loss: 0.6022 - val_root_mean_squared_error: 0.3462
# Epoch 65/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4787 - root_mean_squared_error: 0.2537 - val_loss: 0.6017 - val_root_mean_squared_error: 0.3458
# Epoch 66/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4760 - root_mean_squared_error: 0.2527 - val_loss: 0.6006 - val_root_mean_squared_error: 0.3451
# Epoch 67/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4745 - root_mean_squared_error: 0.2509 - val_loss: 0.5996 - val_root_mean_squared_error: 0.3443
# Epoch 68/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4718 - root_mean_squared_error: 0.2494 - val_loss: 0.5980 - val_root_mean_squared_error: 0.3433
# Epoch 69/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4635 - root_mean_squared_error: 0.2441 - val_loss: 0.5953 - val_root_mean_squared_error: 0.3418
# Epoch 70/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4691 - root_mean_squared_error: 0.2476 - val_loss: 0.5938 - val_root_mean_squared_error: 0.3409
# Epoch 71/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4694 - root_mean_squared_error: 0.2501 - val_loss: 0.5946 - val_root_mean_squared_error: 0.3412
# Epoch 72/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4718 - root_mean_squared_error: 0.2497 - val_loss: 0.5949 - val_root_mean_squared_error: 0.3417
# Epoch 73/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4659 - root_mean_squared_error: 0.2459 - val_loss: 0.5948 - val_root_mean_squared_error: 0.3418
# Epoch 74/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4698 - root_mean_squared_error: 0.2484 - val_loss: 0.5931 - val_root_mean_squared_error: 0.3407
# Epoch 75/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4707 - root_mean_squared_error: 0.2494 - val_loss: 0.5921 - val_root_mean_squared_error: 0.3402
# Epoch 76/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4658 - root_mean_squared_error: 0.2460 - val_loss: 0.5952 - val_root_mean_squared_error: 0.3421
# Epoch 77/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4631 - root_mean_squared_error: 0.2442 - val_loss: 0.5958 - val_root_mean_squared_error: 0.3426
# Epoch 78/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4645 - root_mean_squared_error: 0.2456 - val_loss: 0.5939 - val_root_mean_squared_error: 0.3414
# Epoch 79/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4672 - root_mean_squared_error: 0.2476 - val_loss: 0.5948 - val_root_mean_squared_error: 0.3420
# Epoch 80/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4593 - root_mean_squared_error: 0.2419 - val_loss: 0.5943 - val_root_mean_squared_error: 0.3417
# Epoch 81/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4649 - root_mean_squared_error: 0.2457 - val_loss: 0.5946 - val_root_mean_squared_error: 0.3419
# Epoch 82/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4611 - root_mean_squared_error: 0.2425 - val_loss: 0.5933 - val_root_mean_squared_error: 0.3410
# Epoch 83/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4628 - root_mean_squared_error: 0.2439 - val_loss: 0.5932 - val_root_mean_squared_error: 0.3411
# Epoch 84/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4599 - root_mean_squared_error: 0.2415 - val_loss: 0.5926 - val_root_mean_squared_error: 0.3407
# Epoch 85/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4578 - root_mean_squared_error: 0.2413 - val_loss: 0.5939 - val_root_mean_squared_error: 0.3415
# Epoch 86/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4571 - root_mean_squared_error: 0.2397 - val_loss: 0.5931 - val_root_mean_squared_error: 0.3409
# Epoch 87/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4584 - root_mean_squared_error: 0.2416 - val_loss: 0.5927 - val_root_mean_squared_error: 0.3408
# Epoch 88/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4568 - root_mean_squared_error: 0.2406 - val_loss: 0.5915 - val_root_mean_squared_error: 0.3400
# Epoch 89/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4613 - root_mean_squared_error: 0.2432 - val_loss: 0.5914 - val_root_mean_squared_error: 0.3401
# Epoch 90/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4526 - root_mean_squared_error: 0.2375 - val_loss: 0.5920 - val_root_mean_squared_error: 0.3404
# Epoch 91/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4527 - root_mean_squared_error: 0.2366 - val_loss: 0.5908 - val_root_mean_squared_error: 0.3397
# Epoch 92/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4554 - root_mean_squared_error: 0.2398 - val_loss: 0.5900 - val_root_mean_squared_error: 0.3392
# Epoch 93/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4563 - root_mean_squared_error: 0.2389 - val_loss: 0.5900 - val_root_mean_squared_error: 0.3394
# Epoch 94/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4559 - root_mean_squared_error: 0.2401 - val_loss: 0.5897 - val_root_mean_squared_error: 0.3392
# Epoch 95/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4548 - root_mean_squared_error: 0.2403 - val_loss: 0.5887 - val_root_mean_squared_error: 0.3385
# Epoch 96/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4531 - root_mean_squared_error: 0.2380 - val_loss: 0.5893 - val_root_mean_squared_error: 0.3386
# Epoch 97/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4470 - root_mean_squared_error: 0.2328 - val_loss: 0.5901 - val_root_mean_squared_error: 0.3391
# Epoch 98/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4492 - root_mean_squared_error: 0.2360 - val_loss: 0.5906 - val_root_mean_squared_error: 0.3394
# Epoch 99/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4505 - root_mean_squared_error: 0.2370 - val_loss: 0.5901 - val_root_mean_squared_error: 0.3390
# Epoch 100/100
# 116/116 [==============================] - 0s 2ms/step - loss: 0.4479 - root_mean_squared_error: 0.2348 - val_loss: 0.5910 - val_root_mean_squared_error: 0.3395

# %% [markdown]
# ## Visualisasi Metrik

# %%
plt.plot(history.history['root_mean_squared_error'])
plt.plot(history.history['val_root_mean_squared_error'])
plt.title('model_metrics')
plt.ylabel('root_mean_squared_error')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ## Mendapatkan rekomendasi resto

# %%
resto_df = resto_new
df = pd.read_csv('rating_final.csv')
 
# Mengambil sample user
user_id = df.userID.sample(1).iloc[0]
resto_visited_by_user = df[df.userID == user_id]
 
# Operator bitwise (~), bisa diketahui di sini https://docs.python.org/3/reference/expressions.html 
resto_not_visited = resto_df[~resto_df['id'].isin(resto_visited_by_user.placeID.values)]['id'] 
resto_not_visited = list(
    set(resto_not_visited)
    .intersection(set(resto_to_resto_encoded.keys()))
)
 
resto_not_visited = [[resto_to_resto_encoded.get(x)] for x in resto_not_visited]
user_encoder = user_to_user_encoded.get(user_id)
user_resto_array = np.hstack(
    ([[user_encoder]] * len(resto_not_visited), resto_not_visited)
)

# %%
ratings = model.predict(user_resto_array).flatten()
 
top_ratings_indices = ratings.argsort()[-10:][::-1]
recommended_resto_ids = [
    resto_encoded_to_resto.get(resto_not_visited[x][0]) for x in top_ratings_indices
]
 
print('Showing recommendations for users: {}'.format(user_id))
print('===' * 9)
print('Resto with high ratings from user')
print('----' * 8)
 
top_resto_user = (
    resto_visited_by_user.sort_values(
        by = 'rating',
        ascending=False
    )
    .head(5)
    .placeID.values
)
 
resto_df_rows = resto_df[resto_df['id'].isin(top_resto_user)]
for row in resto_df_rows.itertuples():
    print(row.resto_name, ':', row.cuisine)
 
print('----' * 8)
print('Top 10 resto recommendation')
print('----' * 8)
 
recommended_resto = resto_df[resto_df['id'].isin(recommended_resto_ids)]
for row in recommended_resto.itertuples():
    print(row.resto_name, ':', row.cuisine)
# Out:
# Showing recommendations for users: U1034
# ===========================
# Resto with high ratings from user
# --------------------------------
# Gordas de morales : Mexican
# El Mundo de la Pasta : Italian
# Restaurante de Mariscos la Langosta : Seafood
# Mcdonalds Parque Tangamanga : Fast_Food
# --------------------------------
# Top 10 resto recommendation
# --------------------------------
# cafe punta del cielo : Cafeteria
# emilianos : Bar_Pub_Brewery
# Restaurant Las Mananitas : International
# Michiko Restaurant Japones : Japanese
# El Herradero Restaurante and Bar : Bar
# Restaurant Bar Hacienda los Martinez : Bar
# Restaurante Bar El Gallinero : Bar
# Restaurante la Parroquia Potosina : Contemporary
# Mariscos El Pescador : Seafood
# Koye Sushi : Chinese
